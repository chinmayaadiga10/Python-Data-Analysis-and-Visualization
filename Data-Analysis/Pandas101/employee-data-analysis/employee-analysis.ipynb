# %%
import numpy as np
import pandas as pd

# %%
python_list=[1,2,3,4,5]
series=pd.Series(python_list)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
dictionary={"Baman":65,"Rahul":52,"Chinmay":89}
series=pd.Series(dictionary)
print(series)
# Out:
# Baman      65
# Rahul      52
# Chinmay    89
# dtype: int64

# %%
df=pd.DataFrame({
    "name":["Rohit","Virat"],
    "runs":[264,183]
})

print(df)
# Out:
#     name  runs
# 0  Rohit   264
# 1  Virat   183

# %%
try:
    df=pd.read_csv("employees_100.csv")
except FileNotFoundError:
    print("you've entered wrong file path! try again")
else:
    print(df)
# Out:
#     employee_id            name    department       city   age salary  \
# 0           184    Swati Kapoor  Data Science    Kolkata  38.0  70719
# 1           154  Kavya Malhotra   engineering     Mumbai   NaN  77058
# 2           171    Manish Desai  Data Science  Hyderabad  23.0  69911
# 3           146        Neha Das   Engineering       Pune  28.0  69993
# 4           145       Isha Nair  Data Science        NaN  32.0  88216
# ..          ...             ...           ...        ...   ...    ...
# 95          161     Nikhil Nair     MARKETING    Chennai  22.0  55740
# 96          172      Neha Desai            HR    Chennai  22.0  52250
# 97          115      Neha Reddy     Marketing    Chennai  43.0    NaN
# 98          193     Priya Nayak            HR        NaN  23.0  56821
# 99          152     Kavya Joshi     Marketing      Delhi  44.0  69499
#
#     experience  performance_score  projects_completed joining_date
# ...

# %%
df.head()
# Out:
#    employee_id            name    department       city   age salary  \
# 0          184    Swati Kapoor  Data Science    Kolkata  38.0  70719
# 1          154  Kavya Malhotra   engineering     Mumbai   NaN  77058
# 2          171    Manish Desai  Data Science  Hyderabad  23.0  69911
# 3          146        Neha Das   Engineering       Pune  28.0  69993
# 4          145       Isha Nair  Data Science        NaN  32.0  88216
#
#    experience  performance_score  projects_completed joining_date
# 0           5                  5                   6   2021-07-02
# 1           1                  8                   8   2024-02-05
# 2           0                  6                  18   2019-04-24
# 3           3                  8                   1   2022-12-13
# 4           8                  8                  14   2019-11-25

# %%
df.tail()
# Out:
#     employee_id         name department     city   age salary  experience  \
# 95          161  Nikhil Nair  MARKETING  Chennai  22.0  55740           0
# 96          172   Neha Desai         HR  Chennai  22.0  52250           0
# 97          115   Neha Reddy  Marketing  Chennai  43.0    NaN          12
# 98          193  Priya Nayak         HR      NaN  23.0  56821           3
# 99          152  Kavya Joshi  Marketing    Delhi  44.0  69499          10
#
#     performance_score  projects_completed joining_date
# 95                  5                  22   2020-04-22
# 96                  5                   7   2020-11-14
# 97                  4                  10   2019-06-06
# 98                  9                  16   2019-08-07
# 99                  7                   4   2022-03-25

# %%
df.sample()
# Out:
#    employee_id         name department       city   age salary  experience  \
# 5          140  Rahul Gupta      Sales  Hyderabad  23.0  52404           0
#
#    performance_score  projects_completed joining_date
# 5                  9                  13   2018-12-27

# %%
df.shape
# Out:
# (100, 10)

# %%
df.dtypes
# Out:
# employee_id             int64
# name                      str
# department                str
# city                      str
# age                   float64
# salary                    str
# experience              int64
# performance_score       int64
# projects_completed      int64
# joining_date              str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   employee_id         100 non-null    int64
#  1   name                100 non-null    str
#  2   department          92 non-null     str
#  3   city                90 non-null     str
#  4   age                 94 non-null     float64
#  5   salary              92 non-null     str
#  6   experience          100 non-null    int64
#  7   performance_score   100 non-null    int64
#  8   projects_completed  100 non-null    int64
#  9   joining_date        100 non-null    str
# dtypes: float64(1), int64(4), str(5)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        employee_id        age  experience  performance_score  \
# count   100.000000  94.000000  100.000000           100.0000
# mean    148.740000  30.861702    4.830000             5.7500
# std      27.420637   6.483397    3.755279             1.7019
# min     101.000000  22.000000    0.000000             2.0000
# 25%     125.750000  25.250000    2.000000             5.0000
# 50%     149.500000  31.000000    4.500000             6.0000
# 75%     171.250000  35.750000    8.000000             7.0000
# max     196.000000  45.000000   17.000000            10.0000
#
#        projects_completed
# count          100.000000
# mean             9.970000
# std              5.332301
# min              0.000000
# 25%              6.000000
# 50%              9.500000
# 75%             13.250000
# max             24.000000

# %%
df.isnull()
# Out:
#     employee_id   name  department   city    age  salary  experience  \
# 0         False  False       False  False  False   False       False
# 1         False  False       False  False   True   False       False
# 2         False  False       False  False  False   False       False
# 3         False  False       False  False  False   False       False
# 4         False  False       False   True  False   False       False
# ..          ...    ...         ...    ...    ...     ...         ...
# 95        False  False       False  False  False   False       False
# 96        False  False       False  False  False   False       False
# 97        False  False       False  False  False    True       False
# 98        False  False       False   True  False   False       False
# 99        False  False       False  False  False   False       False
#
#     performance_score  projects_completed  joining_date
# 0               False               False         False
# ...

# %%
df.isnull().sum()
# Out:
# employee_id            0
# name                   0
# department             8
# city                  10
# age                    6
# salary                 8
# experience             0
# performance_score      0
# projects_completed     0
# joining_date           0
# dtype: int64

# %%
df['salary']
# Out:
# 0     70719
# 1     77058
# 2     69911
# 3     69993
# 4     88216
#       ...
# 95    55740
# 96    52250
# 97      NaN
# 98    56821
# 99    69499
# Name: salary, Length: 100, dtype: str

# %%
df[['name','city']]
# Out:
#               name       city
# 0     Swati Kapoor    Kolkata
# 1   Kavya Malhotra     Mumbai
# 2     Manish Desai  Hyderabad
# 3         Neha Das       Pune
# 4        Isha Nair        NaN
# ..             ...        ...
# 95     Nikhil Nair    Chennai
# 96      Neha Desai    Chennai
# 97      Neha Reddy    Chennai
# 98     Priya Nayak        NaN
# 99     Kavya Joshi      Delhi
#
# [100 rows x 2 columns]

# %%
df[['name','city']].head()
# Out:
#              name       city
# 0    Swati Kapoor    Kolkata
# 1  Kavya Malhotra     Mumbai
# 2    Manish Desai  Hyderabad
# 3        Neha Das       Pune
# 4       Isha Nair        NaN

# %%
#df=df.set_index("employee_id") # this line was commented after execution
print(df)
# Out:
#     employee_id            name    department       city   age salary  \
# 0           184    Swati Kapoor  Data Science    Kolkata  38.0  70719
# 1           154  Kavya Malhotra   engineering     Mumbai   NaN  77058
# 2           171    Manish Desai  Data Science  Hyderabad  23.0  69911
# 3           146        Neha Das   Engineering       Pune  28.0  69993
# 4           145       Isha Nair  Data Science        NaN  32.0  88216
# ..          ...             ...           ...        ...   ...    ...
# 95          161     Nikhil Nair     MARKETING    Chennai  22.0  55740
# 96          172      Neha Desai            HR    Chennai  22.0  52250
# 97          115      Neha Reddy     Marketing    Chennai  43.0    NaN
# 98          193     Priya Nayak            HR        NaN  23.0  56821
# 99          152     Kavya Joshi     Marketing      Delhi  44.0  69499
#
#     experience  performance_score  projects_completed joining_date
# ...

# %%
df.head()
# Out:
#    employee_id            name    department       city   age salary  \
# 0          184    Swati Kapoor  Data Science    Kolkata  38.0  70719
# 1          154  Kavya Malhotra   engineering     Mumbai   NaN  77058
# 2          171    Manish Desai  Data Science  Hyderabad  23.0  69911
# 3          146        Neha Das   Engineering       Pune  28.0  69993
# 4          145       Isha Nair  Data Science        NaN  32.0  88216
#
#    experience  performance_score  projects_completed joining_date
# 0           5                  5                   6   2021-07-02
# 1           1                  8                   8   2024-02-05
# 2           0                  6                  18   2019-04-24
# 3           3                  8                   1   2022-12-13
# 4           8                  8                  14   2019-11-25

# %%
df.loc[0]
# Out:
# employee_id                    184
# name                  Swati Kapoor
# department            Data Science
# city                       Kolkata
# age                           38.0
# salary                       70719
# experience                       5
# performance_score                5
# projects_completed               6
# joining_date            2021-07-02
# Name: 0, dtype: object

# %%
df.loc[184:145]
# Out:
# Empty DataFrame
# Columns: [employee_id, name, department, city, age, salary, experience, performance_score, projects_completed, joining_date]
# Index: []

# %%
df.iloc[0]
# Out:
# employee_id                    184
# name                  Swati Kapoor
# department            Data Science
# city                       Kolkata
# age                           38.0
# salary                       70719
# experience                       5
# performance_score                5
# projects_completed               6
# joining_date            2021-07-02
# Name: 0, dtype: object

# %%
df.iloc[0:10]
# Out:
#    employee_id             name    department       city   age salary  \
# 0          184     Swati Kapoor  Data Science    Kolkata  38.0  70719
# 1          154   Kavya Malhotra   engineering     Mumbai   NaN  77058
# 2          171     Manish Desai  Data Science  Hyderabad  23.0  69911
# 3          146         Neha Das   Engineering       Pune  28.0  69993
# 4          145        Isha Nair  Data Science        NaN  32.0  88216
# 5          140      Rahul Gupta         Sales  Hyderabad  23.0  52404
# 6          123       Sneha Iyer            HR  Hyderabad  33.0  59895
# 7          181        Karan Rao     Marketing        NaN  22.0  50733
# 8          111      Kavya Singh   Engineering      Delhi  23.0    NaN
# 9          101  Ananya Malhotra   engineering        NaN  24.0  68591
#
#    experience  performance_score  projects_completed joining_date
# 0           5                  5                   6   2021-07-02
# ...

# %%
df.loc[154:145][["name","city","age","salary"]]
# Out:
# Empty DataFrame
# Columns: [name, city, age, salary]
# Index: []

# %%
df.iloc[1:5][["name","city","age","salary"]]
# Out:
#              name       city   age salary
# 1  Kavya Malhotra     Mumbai   NaN  77058
# 2    Manish Desai  Hyderabad  23.0  69911
# 3        Neha Das       Pune  28.0  69993
# 4       Isha Nair        NaN  32.0  88216

# %%
df['age']>25
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4      True
#       ...
# 95    False
# 96    False
# 97     True
# 98    False
# 99     True
# Name: age, Length: 100, dtype: bool

# %%
df['projects_completed']>10
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4      True
#       ...
# 95     True
# 96    False
# 97    False
# 98     True
# 99    False
# Name: projects_completed, Length: 100, dtype: bool

# %%
df[df['projects_completed']>10]
# Out:
#     employee_id               name    department       city   age  salary  \
# 2           171       Manish Desai  Data Science  Hyderabad  23.0   69911
# 4           145          Isha Nair  Data Science        NaN  32.0   88216
# 5           140        Rahul Gupta         Sales  Hyderabad  23.0   52404
# 6           123         Sneha Iyer            HR  Hyderabad  33.0   59895
# 10          119         Ritu Desai     Marketing       Pune  22.0   55321
# 11          131     Priya Malhotra    Marketing   Hyderabad  25.0   55295
# 12          174   Divya Chatterjee       Finance    Kolkata  24.0   58374
# 13          134     Vivek Kulkarni       Finance    Kolkata  24.0   59422
# 14          191      Neha Malhotra     Marketing     Mumbai  29.0   64944
# 16          177     Vivek Malhotra      Finance   Bangalore   NaN     NaN
# 19          132     Swati Malhotra   Engineering    Chennai  33.0   77222
# 21          189        Anjali Shah     Marketing      Delhi  33.0   56321
# ...

# %%
df[df['age']>30]
# Out:
#     employee_id               name    department       city   age  salary  \
# 0           184       Swati Kapoor  Data Science    Kolkata  38.0   70719
# 4           145          Isha Nair  Data Science        NaN  32.0   88216
# 6           123         Sneha Iyer            HR  Hyderabad  33.0   59895
# 15          105       Vivek Pillai   Engineering       Pune  39.0     NaN
# 18          113          Ritu Nair       Finance        NaN  41.0   74778
# 19          132     Swati Malhotra   Engineering    Chennai  33.0   77222
# 21          189        Anjali Shah     Marketing      Delhi  33.0   56321
# 23          143           Neha Rao         Sales  Hyderabad  37.0     NaN
# 27          162  Suresh Chatterjee           HR   Hyderabad  32.0   59273
# 30          112       Aditya Reddy       Finance        NaN  31.0   58811
# 32          186       Rohan Kapoor           NaN       Pune  36.0   65152
# 36          167     Meera Malhotra            HR  Hyderabad  31.0   48822
# ...

# %%
df['department']=="Finance"
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: department, Length: 100, dtype: bool

# %%
df[df['department']=="Finance"]
# Out:
#     employee_id              name department       city   age  salary  \
# 12          174  Divya Chatterjee    Finance    Kolkata  24.0   58374
# 13          134    Vivek Kulkarni    Finance    Kolkata  24.0   59422
# 18          113         Ritu Nair    Finance        NaN  41.0   74778
# 30          112      Aditya Reddy    Finance        NaN  31.0   58811
# 52          118       Rajesh Nair    Finance  Hyderabad  26.0   67464
# 55          179         Arjun Das    Finance        NaN  43.0     NaN
# 58          137         Ritu Bose    Finance  Bangalore  38.0   71062
# 64          151       Sneha Verma    Finance      Delhi   NaN   66422
# 69          134    Vivek Kulkarni    Finance    Kolkata  24.0   59422
# 70          180    Ashok Kulkarni    Finance    Kolkata  31.0   58777
# 76          176      Shreya Menon    Finance        NaN  41.0   80597
# 78          195        Pooja Nair    Finance        NaN  33.0   69396
# ...

# %%
(df['department']=="Finance") & (df['age']>30)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df[(df['department']=="Finance") & (df['age']>30)]
# Out:
#     employee_id            name department       city   age  salary  \
# 18          113       Ritu Nair    Finance        NaN  41.0   74778
# 30          112    Aditya Reddy    Finance        NaN  31.0   58811
# 55          179       Arjun Das    Finance        NaN  43.0     NaN
# 58          137       Ritu Bose    Finance  Bangalore  38.0   71062
# 70          180  Ashok Kulkarni    Finance    Kolkata  31.0   58777
# 76          176    Shreya Menon    Finance        NaN  41.0   80597
# 78          195      Pooja Nair    Finance        NaN  33.0   69396
# 79          160    Shreya Singh    Finance       Pune  38.0   62020
# 82          138     Rahul Gupta    Finance  Hyderabad  35.0  75,614
#
#     experience  performance_score  projects_completed joining_date
# 18          10                  7                   5   2018-02-13
# 30           2                  3                   3   2020-05-26
# 55          10                  7                  11   2024-08-25
# ...

# %% [markdown]
# #### Finding people in either sales or finance department, with experience greater than 5 years and age greater than 30

# %%
df[((df['department']=="Finance") | (df['department']=="Marketing")) & ((df['age']>30)&(df['experience']>3))]
# Out:
#     employee_id          name department       city   age  salary  experience  \
# 18          113     Ritu Nair    Finance        NaN  41.0   74778          10
# 21          189   Anjali Shah  Marketing      Delhi  33.0   56321           6
# 50          125    Sneha Bose  Marketing     Mumbai  32.0   56627           7
# 51          104     Ritu Iyer  Marketing  Bangalore  34.0   63574           8
# 55          179     Arjun Das    Finance        NaN  43.0     NaN          10
# 57          165      Isha Das  Marketing       Pune  40.0   57895           6
# 58          137     Ritu Bose    Finance  Bangalore  38.0   71062           8
# 76          176  Shreya Menon    Finance        NaN  41.0   80597           9
# 78          195    Pooja Nair    Finance        NaN  33.0   69396           6
# 79          160  Shreya Singh    Finance       Pune  38.0   62020           5
# 82          138   Rahul Gupta    Finance  Hyderabad  35.0  75,614          11
# ...

# %% [markdown]
# ### Data Cleaning Operations

# %%
df.isnull()
# Out:
#     employee_id   name  department   city    age  salary  experience  \
# 0         False  False       False  False  False   False       False
# 1         False  False       False  False   True   False       False
# 2         False  False       False  False  False   False       False
# 3         False  False       False  False  False   False       False
# 4         False  False       False   True  False   False       False
# ..          ...    ...         ...    ...    ...     ...         ...
# 95        False  False       False  False  False   False       False
# 96        False  False       False  False  False   False       False
# 97        False  False       False  False  False    True       False
# 98        False  False       False   True  False   False       False
# 99        False  False       False  False  False   False       False
#
#     performance_score  projects_completed  joining_date
# 0               False               False         False
# ...

# %%
df.isnull().sum()
# Out:
# employee_id            0
# name                   0
# department             8
# city                  10
# age                    6
# salary                 8
# experience             0
# performance_score      0
# projects_completed     0
# joining_date           0
# dtype: int64

# %%
df.dropna()
# Out:
#     employee_id          name    department       city   age salary  \
# 0           184  Swati Kapoor  Data Science    Kolkata  38.0  70719
# 2           171  Manish Desai  Data Science  Hyderabad  23.0  69911
# 3           146      Neha Das   Engineering       Pune  28.0  69993
# 5           140   Rahul Gupta         Sales  Hyderabad  23.0  52404
# 6           123    Sneha Iyer            HR  Hyderabad  33.0  59895
# ..          ...           ...           ...        ...   ...    ...
# 93          183  Deepak Nayak     Marketing  Hyderabad  28.0  62393
# 94          121    Ashok Shah  Data Science       Pune  31.0  75498
# 95          161   Nikhil Nair     MARKETING    Chennai  22.0  55740
# 96          172    Neha Desai            HR    Chennai  22.0  52250
# 99          152   Kavya Joshi     Marketing      Delhi  44.0  69499
#
#     experience  performance_score  projects_completed joining_date
# 0            5                  5                   6   2021-07-02
# ...

# %%
df.dropna(subset=['city'])
# Out:
#     employee_id            name    department       city   age salary  \
# 0           184    Swati Kapoor  Data Science    Kolkata  38.0  70719
# 1           154  Kavya Malhotra   engineering     Mumbai   NaN  77058
# 2           171    Manish Desai  Data Science  Hyderabad  23.0  69911
# 3           146        Neha Das   Engineering       Pune  28.0  69993
# 5           140     Rahul Gupta         Sales  Hyderabad  23.0  52404
# ..          ...             ...           ...        ...   ...    ...
# 94          121      Ashok Shah  Data Science       Pune  31.0  75498
# 95          161     Nikhil Nair     MARKETING    Chennai  22.0  55740
# 96          172      Neha Desai            HR    Chennai  22.0  52250
# 97          115      Neha Reddy     Marketing    Chennai  43.0    NaN
# 99          152     Kavya Joshi     Marketing      Delhi  44.0  69499
#
#     experience  performance_score  projects_completed joining_date
# ...

# %%
df.dropna(subset=['city','age'])
# Out:
#     employee_id          name    department       city   age salary  \
# 0           184  Swati Kapoor  Data Science    Kolkata  38.0  70719
# 2           171  Manish Desai  Data Science  Hyderabad  23.0  69911
# 3           146      Neha Das   Engineering       Pune  28.0  69993
# 5           140   Rahul Gupta         Sales  Hyderabad  23.0  52404
# 6           123    Sneha Iyer            HR  Hyderabad  33.0  59895
# ..          ...           ...           ...        ...   ...    ...
# 94          121    Ashok Shah  Data Science       Pune  31.0  75498
# 95          161   Nikhil Nair     MARKETING    Chennai  22.0  55740
# 96          172    Neha Desai            HR    Chennai  22.0  52250
# 97          115    Neha Reddy     Marketing    Chennai  43.0    NaN
# 99          152   Kavya Joshi     Marketing      Delhi  44.0  69499
#
#     experience  performance_score  projects_completed joining_date
# 0            5                  5                   6   2021-07-02
# ...

# %%
df.head()
# Out:
#    employee_id            name    department       city   age salary  \
# 0          184    Swati Kapoor  Data Science    Kolkata  38.0  70719
# 1          154  Kavya Malhotra   engineering     Mumbai   NaN  77058
# 2          171    Manish Desai  Data Science  Hyderabad  23.0  69911
# 3          146        Neha Das   Engineering       Pune  28.0  69993
# 4          145       Isha Nair  Data Science        NaN  32.0  88216
#
#    experience  performance_score  projects_completed joining_date
# 0           5                  5                   6   2021-07-02
# 1           1                  8                   8   2024-02-05
# 2           0                  6                  18   2019-04-24
# 3           3                  8                   1   2022-12-13
# 4           8                  8                  14   2019-11-25

# %%
df['age'].fillna(df['age'].mean())
# Out:
# 0     38.000000
# 1     30.861702
# 2     23.000000
# 3     28.000000
# 4     32.000000
#         ...
# 95    22.000000
# 96    22.000000
# 97    43.000000
# 98    23.000000
# 99    44.000000
# Name: age, Length: 100, dtype: float64

# %%
df.isnull().sum()
# Out:
# employee_id            0
# name                   0
# department             8
# city                  10
# age                    6
# salary                 8
# experience             0
# performance_score      0
# projects_completed     0
# joining_date           0
# dtype: int64

# %%
df['salary']=df['salary'].str.replace(",","",regex=False)
df['salary']=pd.to_numeric(df['salary'],errors='coerce')
df['salary'].fillna(df['salary'].median())
# Out:
# 0     70719.0
# 1     77058.0
# 2     69911.0
# 3     69993.0
# 4     88216.0
#        ...
# 95    55740.0
# 96    52250.0
# 97    62969.5
# 98    56821.0
# 99    69499.0
# Name: salary, Length: 100, dtype: float64

# %%
df['department'].value_counts()
# Out:
# department
# HR              17
# Marketing       17
# Finance         16
# Engineering     14
# Data Science    10
# Sales            8
# engineering      3
#  HR              2
#  Marketing       1
#  Finance         1
# FINANCE          1
# SALES            1
# MARKETING        1
# Name: count, dtype: int64

# %%
df['department']=df['department'].fillna(df['department'].mode()[0])

# %%
df['city'].value_counts()
# Out:
# city
# Hyderabad    19
# Pune         14
# Delhi        14
# Kolkata      13
# Mumbai       10
# Bangalore    10
# Chennai      10
# Name: count, dtype: int64

# %%
df['city']=df['city'].fillna(df['city'].mode()[0])

# %%
df.isnull().sum()
# Out:
# employee_id           0
# name                  0
# department            0
# city                  0
# age                   6
# salary                8
# experience            0
# performance_score     0
# projects_completed    0
# joining_date          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.reset_index()

# %%
df
# Out:
#     index  employee_id            name    department       city   age  \
# 0       0          184    Swati Kapoor  Data Science    Kolkata  38.0
# 1       1          154  Kavya Malhotra   engineering     Mumbai   NaN
# 2       2          171    Manish Desai  Data Science  Hyderabad  23.0
# 3       3          146        Neha Das   Engineering       Pune  28.0
# 4       4          145       Isha Nair  Data Science  Hyderabad  32.0
# ..    ...          ...             ...           ...        ...   ...
# 95     95          161     Nikhil Nair     MARKETING    Chennai  22.0
# 96     96          172      Neha Desai            HR    Chennai  22.0
# 97     97          115      Neha Reddy     Marketing    Chennai  43.0
# 98     98          193     Priya Nayak            HR  Hyderabad  23.0
# 99     99          152     Kavya Joshi     Marketing      Delhi  44.0
#
#      salary  experience  performance_score  projects_completed joining_date
# ...

# %%
df.duplicated(subset=["employee_id"]).sum()
# Out:
# np.int64(4)

# %%
df.drop_duplicates(subset=["employee_id"],keep="first",inplace=True)

# %%
df['joining_date']=pd.to_datetime(df['joining_date'])

# %%
df
# Out:
#     index  employee_id            name    department       city   age  \
# 0       0          184    Swati Kapoor  Data Science    Kolkata  38.0
# 1       1          154  Kavya Malhotra   engineering     Mumbai   NaN
# 2       2          171    Manish Desai  Data Science  Hyderabad  23.0
# 3       3          146        Neha Das   Engineering       Pune  28.0
# 4       4          145       Isha Nair  Data Science  Hyderabad  32.0
# ..    ...          ...             ...           ...        ...   ...
# 95     95          161     Nikhil Nair     MARKETING    Chennai  22.0
# 96     96          172      Neha Desai            HR    Chennai  22.0
# 97     97          115      Neha Reddy     Marketing    Chennai  43.0
# 98     98          193     Priya Nayak            HR  Hyderabad  23.0
# 99     99          152     Kavya Joshi     Marketing      Delhi  44.0
#
#      salary  experience  performance_score  projects_completed joining_date
# ...

# %% [markdown]
# ### Modifying Data and Creating New Columns

# %%
df['annual_salary']=df['salary']*12

# %%
df.head()
# Out:
#    index  employee_id            name    department       city   age   salary  \
# 0      0          184    Swati Kapoor  Data Science    Kolkata  38.0  70719.0
# 1      1          154  Kavya Malhotra   engineering     Mumbai   NaN  77058.0
# 2      2          171    Manish Desai  Data Science  Hyderabad  23.0  69911.0
# 3      3          146        Neha Das   Engineering       Pune  28.0  69993.0
# 4      4          145       Isha Nair  Data Science  Hyderabad  32.0  88216.0
#
#    experience  performance_score  projects_completed joining_date  \
# 0           5                  5                   6   2021-07-02
# 1           1                  8                   8   2024-02-05
# 2           0                  6                  18   2019-04-24
# 3           3                  8                   1   2022-12-13
# 4           8                  8                  14   2019-11-25
#
#    annual_salary
# 0       848628.0
# 1       924696.0
# 2       838932.0
# 3       839916.0
# ...

# %%
def categorize(number):
    if number>5:
        return "Experienced Candidate"
    elif number<=5:
        return "Learner"

# %%
df['experience_status']=df['experience'].apply(categorize)

# %%
df.head()
# Out:
#    index  employee_id            name    department       city   age   salary  \
# 0      0          184    Swati Kapoor  Data Science    Kolkata  38.0  70719.0
# 1      1          154  Kavya Malhotra   engineering     Mumbai   NaN  77058.0
# 2      2          171    Manish Desai  Data Science  Hyderabad  23.0  69911.0
# 3      3          146        Neha Das   Engineering       Pune  28.0  69993.0
# 4      4          145       Isha Nair  Data Science  Hyderabad  32.0  88216.0
#
#    experience  performance_score  projects_completed joining_date  \
# 0           5                  5                   6   2021-07-02
# 1           1                  8                   8   2024-02-05
# 2           0                  6                  18   2019-04-24
# 3           3                  8                   1   2022-12-13
# 4           8                  8                  14   2019-11-25
#
#    annual_salary      experience_status
# 0       848628.0                Learner
# ...

# %% [markdown]
# ### Sorting and Ranking

# %%
df.sort_values(by="salary")
# Out:
#     index  employee_id              name   department       city   age  \
# 26     26          141   Manish Kulkarni           HR    Chennai  27.0
# 36     36          167    Meera Malhotra           HR  Hyderabad  31.0
# 33     33          129       Ashok Gupta    Marketing  Hyderabad  22.0
# 67     67          169  Swati Chatterjee           HR       Pune  33.0
# 7       7          181         Karan Rao    Marketing  Hyderabad  22.0
# ..    ...          ...               ...          ...        ...   ...
# 23     23          143          Neha Rao        Sales  Hyderabad  37.0
# 45     45          120        Isha Gupta    Marketing     Mumbai  26.0
# 55     55          179         Arjun Das      Finance  Hyderabad  43.0
# 60     60          157        Ananya Rao  Engineering     Mumbai  25.0
# 97     97          115        Neha Reddy    Marketing    Chennai  43.0
#
#      salary  experience  performance_score  projects_completed joining_date  \
# ...

# %%
df.sort_values(by="salary",ascending=False)
# Out:
#     index  employee_id            name    department       city   age  \
# 74     74          158  Tanvi Malhotra            HR     Mumbai  32.0
# 4       4          145       Isha Nair  Data Science  Hyderabad  32.0
# 88     88          124    Deepak Verma  Data Science  Hyderabad  41.0
# 84     84          102     Rahul Menon   Engineering  Hyderabad  38.0
# 39     39          117  Pooja Malhotra   engineering    Kolkata  24.0
# ..    ...          ...             ...           ...        ...   ...
# 23     23          143        Neha Rao         Sales  Hyderabad  37.0
# 45     45          120      Isha Gupta     Marketing     Mumbai  26.0
# 55     55          179       Arjun Das       Finance  Hyderabad  43.0
# 60     60          157      Ananya Rao   Engineering     Mumbai  25.0
# 97     97          115      Neha Reddy     Marketing    Chennai  43.0
#
#      salary  experience  performance_score  projects_completed joining_date  \
# ...

# %%
df['department'].unique()
# Out:
# <StringArray>
# ['Data Science',  'engineering',  'Engineering',        'Sales',
#            'HR',    'Marketing',  ' Marketing ',      'Finance',
#     ' Finance ',         ' HR ',      'FINANCE',        'SALES',
#     'MARKETING']
# Length: 13, dtype: str

# %%
df['department']=df['department'].str.strip().str.title()

# %%
df['department'].unique()
# Out:
# <StringArray>
# ['Data Science', 'Engineering', 'Sales', 'Hr', 'Marketing', 'Finance']
# Length: 6, dtype: str

# %%
result=df.sort_values(by=['department','salary'],ascending=[True,False])
result
# Out:
#     index  employee_id              name    department       city   age  \
# 4       4          145         Isha Nair  Data Science  Hyderabad  32.0
# 88     88          124      Deepak Verma  Data Science  Hyderabad  41.0
# 59     59          190        Swati Bose  Data Science     Mumbai  22.0
# 24     24          170        Rahul Nair  Data Science    Kolkata  30.0
# 54     54          109    Rohan Kulkarni  Data Science      Delhi  28.0
# ..    ...          ...               ...           ...        ...   ...
# 17     17          178     Vikram Kapoor         Sales    Chennai  29.0
# 44     44          128  Rohan Chatterjee         Sales     Mumbai  26.0
# 38     38          136      Sanjay Mehta         Sales  Hyderabad  30.0
# 5       5          140       Rahul Gupta         Sales  Hyderabad  23.0
# 23     23          143          Neha Rao         Sales  Hyderabad  37.0
#
#      salary  experience  performance_score  projects_completed joining_date  \
# ...

# %%
df['salary_rank']=df['salary'].rank(ascending=False)

# %%
df.head()
# Out:
#    index  employee_id            name    department       city   age   salary  \
# 0      0          184    Swati Kapoor  Data Science    Kolkata  38.0  70719.0
# 1      1          154  Kavya Malhotra   Engineering     Mumbai   NaN  77058.0
# 2      2          171    Manish Desai  Data Science  Hyderabad  23.0  69911.0
# 3      3          146        Neha Das   Engineering       Pune  28.0  69993.0
# 4      4          145       Isha Nair  Data Science  Hyderabad  32.0  88216.0
#
#    experience  performance_score  projects_completed joining_date  \
# 0           5                  5                   6   2021-07-02
# 1           1                  8                   8   2024-02-05
# 2           0                  6                  18   2019-04-24
# 3           3                  8                   1   2022-12-13
# 4           8                  8                  14   2019-11-25
#
#    annual_salary      experience_status  salary_rank
# ...

# %%
df.sort_values(by="salary_rank")
# Out:
#     index  employee_id            name    department       city   age  \
# 74     74          158  Tanvi Malhotra            Hr     Mumbai  32.0
# 4       4          145       Isha Nair  Data Science  Hyderabad  32.0
# 88     88          124    Deepak Verma  Data Science  Hyderabad  41.0
# 84     84          102     Rahul Menon   Engineering  Hyderabad  38.0
# 39     39          117  Pooja Malhotra   Engineering    Kolkata  24.0
# ..    ...          ...             ...           ...        ...   ...
# 23     23          143        Neha Rao         Sales  Hyderabad  37.0
# 45     45          120      Isha Gupta     Marketing     Mumbai  26.0
# 55     55          179       Arjun Das       Finance  Hyderabad  43.0
# 60     60          157      Ananya Rao   Engineering     Mumbai  25.0
# 97     97          115      Neha Reddy     Marketing    Chennai  43.0
#
#      salary  experience  performance_score  projects_completed joining_date  \
# ...

# %%
df.nlargest(5,"age")
# Out:
#     index  employee_id         name department       city   age   salary  \
# 62     62          155   Sanjay Das         Hr  Bangalore  45.0  74505.0
# 99     99          152  Kavya Joshi  Marketing      Delhi  44.0  69499.0
# 55     55          179    Arjun Das    Finance  Hyderabad  43.0      NaN
# 97     97          115   Neha Reddy  Marketing    Chennai  43.0      NaN
# 61     61          164  Sneha Gupta         Hr      Delhi  42.0  63209.0
#
#     experience  performance_score  projects_completed joining_date  \
# 62          17                  6                  10   2022-06-22
# 99          10                  7                   4   2022-03-25
# 55          10                  7                  11   2024-08-25
# 97          12                  4                  10   2019-06-06
# 61          11                  3                   8   2021-08-07
#
#     annual_salary      experience_status  salary_rank
# 62       894060.0  Experienced Candidate         22.0
# ...

# %%
df.nsmallest(5,"performance_score")
# Out:
#     index  employee_id              name    department       city   age  \
# 20     20          156     Aditya Kapoor  Data Science    Kolkata  26.0
# 24     24          170        Rahul Nair  Data Science    Kolkata  30.0
# 50     50          125        Sneha Bose     Marketing     Mumbai  32.0
# 76     76          176      Shreya Menon       Finance  Hyderabad  41.0
# 12     12          174  Divya Chatterjee       Finance    Kolkata  24.0
#
#      salary  experience  performance_score  projects_completed joining_date  \
# 20  69765.0           0                  2                   4   2020-04-12
# 24  76425.0           5                  2                   4   2021-06-25
# 50  56627.0           7                  2                   9   2023-07-12
# 76  80597.0           9                  2                  18   2024-11-09
# 12  58374.0           1                  3                  12   2018-09-21
#
#     annual_salary      experience_status  salary_rank
# ...

# %% [markdown]
# ### Grouping and Aggregation

# %%
df['city'].unique()
# Out:
# <StringArray>
# ['Kolkata', 'Mumbai', 'Hyderabad', 'Pune', 'Delhi', 'Bangalore', 'Chennai']
# Length: 7, dtype: str

# %%
df['city'].nunique()
# Out:
# 7

# %%
df
# Out:
#     index  employee_id            name    department       city   age  \
# 0       0          184    Swati Kapoor  Data Science    Kolkata  38.0
# 1       1          154  Kavya Malhotra   Engineering     Mumbai   NaN
# 2       2          171    Manish Desai  Data Science  Hyderabad  23.0
# 3       3          146        Neha Das   Engineering       Pune  28.0
# 4       4          145       Isha Nair  Data Science  Hyderabad  32.0
# ..    ...          ...             ...           ...        ...   ...
# 95     95          161     Nikhil Nair     Marketing    Chennai  22.0
# 96     96          172      Neha Desai            Hr    Chennai  22.0
# 97     97          115      Neha Reddy     Marketing    Chennai  43.0
# 98     98          193     Priya Nayak            Hr  Hyderabad  23.0
# 99     99          152     Kavya Joshi     Marketing      Delhi  44.0
#
#      salary  experience  performance_score  projects_completed joining_date  \
# ...

# %%
df.groupby('city')

# %%
df.groupby('city')['age'].mean()
# Out:
# city
# Bangalore    34.375000
# Chennai      29.250000
# Delhi        33.250000
# Hyderabad    30.892857
# Kolkata      28.000000
# Mumbai       27.375000
# Pune         31.642857
# Name: age, dtype: float64

# %%
df.groupby('city')['salary'].max()
# Out:
# city
# Bangalore    81112.0
# Chennai      77222.0
# Delhi        80358.0
# Hyderabad    88216.0
# Kolkata      84255.0
# Mumbai       88366.0
# Pune         78545.0
# Name: salary, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 96 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               96 non-null     int64
#  1   employee_id         96 non-null     int64
#  2   name                96 non-null     str
#  3   department          96 non-null     str
#  4   city                96 non-null     str
#  5   age                 90 non-null     float64
#  6   salary              88 non-null     float64
#  7   experience          96 non-null     int64
#  8   performance_score   96 non-null     int64
#  9   projects_completed  96 non-null     int64
#  10  joining_date        96 non-null     datetime64[us]
#  11  annual_salary       88 non-null     float64
#  12  experience_status   96 non-null     str
#  13  salary_rank         88 non-null     float64
# dtypes: datetime64[us](1), float64(4), int64(5), str(4)
# memory usage: 11.2 KB

# %%
df.sample()
# Out:
#     index  employee_id        name   department     city  age   salary  \
# 31     31          148  Kavya Nair  Engineering  Chennai  NaN  76320.0
#
#     experience  performance_score  projects_completed joining_date  \
# 31           3                  7                  11   2024-03-07
#
#     annual_salary experience_status  salary_rank
# 31       915840.0           Learner         15.0
